# %% [markdown]
# # Dictionaries & Pandas
# - Voer onderstaande cel uit om de st_to dictionary aan te maken.

# %%
#Creating dictionary from columns in dataframe
import pandas as pd
storedata = pd.read_csv('storedata_clean.csv', encoding = "ISO-8859-1",sep=";")

store_id = storedata['Store ID'].values.tolist()
turnover = storedata['Profit'].values.tolist()
floor = storedata['Floor Space'].values.tolist()


st_to = dict(zip(store_id, turnover))

# %% [markdown]
# ### 1.1 Printen dictionary
# St_to bevat de winkelnummers (store id) en de omzet (turnover) van iedere winkel.
# - Print st_to.

# %%
display(st_to)
# Out:
# {1437: 3410865,
#  1544: 4034051,
#  2039: 2297810,
#  2055: 2398990,
#  2141: 2288235,
#  2309: 3058134,
#  3800: 2793160,
#  4214: 3345936,
#  4857: 3117205,
#  4860: 3153278,
#  7491: 3056804,
#  7566: 1801619,
#  8207: 3797953,
#  9171: 3138911,
#  11440: 2724068,
#  13132: 2382751,
#  13984: 3321899,
#  14359: 2803867,
#  14421: 3640627,
#  14984: 3075352,
#  15125: 3491993,
#  16727: 3252148,
#  16741: 3041618,
#  18554: 3737466,
#  19296: 4217291,
#  20304: 2008363,
#  20971: 3516397,
#  21359: 3957233,
#  23025: 2942839,
#  23231: 2242288,
#  23249: 2616387,
#  23705: 2493975,
#  24174: 2203994,
#  24618: 2458785,
#  24737: 4253984,
#  26307: 4185306,
#  29319: 4160531,
#  32610: 3100521,
#  34686: 3246954,
#  35207: 2085733,
#  35944: 3741911,
#  36979: 2506748,
#  37708: 2393869,
#  37916: 4137224,
#  40352: 3572475,
#  40676: 3121837,
#  41475: 2799074,
#  42172: 2707402,
#  42797: 4176642,
#  42943: 1829621,
#  43044: 2681110,
#  43066: 2411437,
#  44476: 4300537,
# ...

# %% [markdown]
# ## 2 Single dictionaries
# Opdrachten:
#
# - Print de omzet van winkel 13132
# - Voeg winkel 99999 met een omzet van 3100000 toe aan de dictionary.
# - Print de omzet van 99999.
# - Vervang de omzet van 99999 met 3200000 en print de nieuwe omzet.
# - Verwijder winkel 99999 en controleer dit door te testen of je de omzet nog kunt printen.

# %%
#print turnover of store 13132
print(st_to[13132])

#Add store 99999 with turnover of 3100000. Print the turnover
st_to[99999] = 3_100_000

#Update turnover of the new store to 3200000 and print the turnover
st_to[99999] = 3_200_000

st_to.update({99999:33000})

#delete the new store and check deletion by attempting to print it again
del(st_to[99999])
print(st_to[99999])
# Out:
# 2382751
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7548\978197684.py in <module>
#      12 #delete the new store and check deletion by attempting to print it again
#      13 del(st_to[99999])
# ---> 14 print(st_to[99999])
#
# KeyError: 99999

# %% [markdown]
# ## 3 Nested dictionaries
# - Voer onderstaande cel uit om de dictionary st_to_fl aan te maken.

# %%
#Creating a nested dictionary
st_to_fl = dict(map(lambda x, y, z : (x, {"turnover":y , "floor":z}), store_id, turnover, floor))

# %% [markdown]
# - Print st_to_fl en bestudeer de structuur van deze 'nested' dictionary.

# %%
#Get an understanding of the structure of the dictionary
display(st_to_fl)
# Out:
# {1437: {'turnover': 3410865, 'floor': 18526},
#  1544: {'turnover': 4034051, 'floor': 18569},
#  2039: {'turnover': 2297810, 'floor': 12288},
#  2055: {'turnover': 2398990, 'floor': 17092},
#  2141: {'turnover': 2288235, 'floor': 11307},
#  2309: {'turnover': 3058134, 'floor': 17888},
#  3800: {'turnover': 2793160, 'floor': 13814},
#  4214: {'turnover': 3345936, 'floor': 15643},
#  4857: {'turnover': 3117205, 'floor': 13869},
#  4860: {'turnover': 3153278, 'floor': 12071},
#  7491: {'turnover': 3056804, 'floor': 13487},
#  7566: {'turnover': 1801619, 'floor': 11071},
#  8207: {'turnover': 3797953, 'floor': 18923},
#  9171: {'turnover': 3138911, 'floor': 13827},
#  11440: {'turnover': 2724068, 'floor': 14588},
#  13132: {'turnover': 2382751, 'floor': 11824},
#  13984: {'turnover': 3321899, 'floor': 14291},
#  14359: {'turnover': 2803867, 'floor': 10911},
#  14421: {'turnover': 3640627, 'floor': 15219},
#  14984: {'turnover': 3075352, 'floor': 12128},
# ...

# %% [markdown]
# - Print de oppervlakte van 13132.
# - Voeg de nieuwe winkel 99999 toe aan de dictionary met een omzet van 3100000 en een oppervlakte van 15000.
# - Print de oppervlakte en de omzet van de nieuwe winkel.
# - Verander de oppervlakte van 99999 in 3200000.
# - Print de omzet van de nieuwe winkel.

# %%
#print floorspace of 13132
print(st_to_fl[13132]["floor"])

#add new store 99999 to the dictionary with turnover of 3100000 and floor space of 15000
st_to_fl[99999] = {"turnover": 3_100_000, "floor": 15000}

#Change turnover into 3200000
st_to_fl[99999]["turnover"] = 3_200_000
print(st_to_fl[99999])
# Out:
# 11824
# {'turnover': 3200000, 'floor': 15000}

# %% [markdown]
# ### 4  Pandas: lezen van csv bestand
# Bekijk onderstaande link:
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html
#
# - Lees storedata_clean.csv in als het dataframe storedata. Houd hierbij rekening met het volgende:
#     - Het scheidingsteken (delimiter) van dit bestand is puntkomma (semicolon).
#     - De indexkolom van het nieuwe bestand dient "Store ID" te zijn.
#
# - Print het dataframe.

# %%
import pandas as pd
import numpy as np
storedata = pd.read_csv("storedata_clean.csv", sep= ";", index_col= "Store ID")
print(storedata)
# Out:
#                                    Town Country Manager name  Staff  \
# Store ID
# 1437       Swinton (Greater Manchester)      UK        Roger      9
# 1544                           Stamford      UK         Ella      8
# 2039                            Skipton      UK    Valentina      2
# 2055                           Stratton      UK      Antonia      7
# 2141                         Shepperton      UK      Gabriel      7
# ...                                 ...     ...          ...    ...
# 96853                    South Benfleet      UK      Vitória      7
# 96858                             Sandy      UK       Matías      6
# 98062                         Sheerness      UK      Gustavo      7
# 98923                           Salford      UK       Rafael      6
# 99854                        Stapleford      UK          Lea      9
#
#           Floor Space  Window Car park  Demographic score         Location  \
# Store ID
# ...

# %% [markdown]
# ### 5 Selecteren, loc and iloc
# - Voer de opdrachten uit zoals gevraagd in de comments van onderstaande cellen:

# %%
# Print de 'Town' kolom als een Pandas Series. Print het type van deze kolom.
print(storedata.iloc[:,0])

# print(storedata["Town"])
# print(type(storedata["Town"]))

print(type(storedata.iloc[:,0]))
# Out:
# Store ID
# 1437      Swinton (Greater Manchester)
# 1544                          Stamford
# 2039                           Skipton
# 2055                          Stratton
# 2141                        Shepperton
#                      ...
# 96853                   South Benfleet
# 96858                            Sandy
# 98062                        Sheerness
# 98923                          Salford
# 99854                       Stapleford
# Name: Town, Length: 136, dtype: object
# Store ID
# 1437      Swinton (Greater Manchester)
# 1544                          Stamford
# 2039                           Skipton
# 2055                          Stratton
# 2141                        Shepperton
#                      ...
# 96853                   South Benfleet
# 96858                            Sandy
# 98062                        Sheerness
# 98923                          Salford
# 99854                       Stapleford
# Name: Town, Length: 136, dtype: object
# ...

# %%
# Print de 'Town' kolom en de 'Staff' kolom als een Pandas DataFrame. Print het type.
print(storedata.iloc[:,[0,3]])
print(type(storedata.iloc[:,[0,3]]))

display(storedata[["Town", "Staff"]])
# Out:
#                                    Town  Staff
# Store ID
# 1437       Swinton (Greater Manchester)      9
# 1544                           Stamford      8
# 2039                            Skipton      2
# 2055                           Stratton      7
# 2141                         Shepperton      7
# ...                                 ...    ...
# 96853                    South Benfleet      7
# 96858                             Sandy      6
# 98062                         Sheerness      7
# 98923                           Salford      6
# 99854                        Stapleford      9
#
# [136 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
#                                    Town  Staff
# Store ID
# 1437       Swinton (Greater Manchester)      9
# 1544                           Stamford      8
# 2039                            Skipton      2
# 2055                           Stratton      7
# 2141                         Shepperton      7
# ...

# %%
#Print de 5e, 6e en 7e observatie (rij) van storedata.
print(storedata.iloc[[4,5,6],:])
# Out:
#                                 Town Country Manager name  Staff  Floor Space  \
# Store ID
# 2141                      Shepperton      UK      Gabriel      7        11307
# 2309                       Southwell      UK        Sarah      7        17888
# 3800       Swinton (South Yorkshire)      UK        James      8        13814
#
#           Window Car park  Demographic score     Location  40min population  \
# Store ID
# 2141         103       No                 18  Retail Park           1398558
# 2309         119      Yes                 19  Retail Park           1614716
# 3800         109      Yes                 17  High Street           1323396
#
#           30 min population  20 min population  10 min population  Store age  \
# Store ID
# 2141                1085170            1003137            1002513          7
# 2309                1325848            1220059            1193318          2
# 3800                1047485            1000888            1000844          5
#
# ...

# %%
#Print de rij van winkel (Store ID) 7566 als een Series. Pas hierbij de loc method toe.
print(storedata.loc[7566, :])
print(type(storedata.loc[7566, :]))
# Out:
# Town                      Staines
# Country                        UK
# Manager name               Olivia
# Staff                           8
# Floor Space                 11071
# Window                        102
# Car park                       No
# Demographic score              12
# Location              Retail Park
# 40min population          1514670
# 30 min population         1400857
# 20 min population         1319646
# 10 min population         1010879
# Store age                      11
# Clearance space               202
# Competition number             15
# Competition score              10
# Profit                    1801619
# Performance                  Poor
# Name: 7566, dtype: object
# <class 'pandas.core.series.Series'>

# %%
#print de rijen van winkels 99854 en 96858 als een dataframe. Pas hierbij de loc method toe.
print(storedata.loc[[99854, 96858], :])
print(type(storedata.loc[[99854, 96858], :]))
# Out:
#                  Town Country Manager name  Staff  Floor Space  Window  \
# Store ID
# 99854      Stapleford      UK          Lea      9        14468     111
# 96858           Sandy      UK       Matías      6        11205     103
#
#          Car park  Demographic score         Location  40min population  \
# Store ID
# 99854         Yes                 18      High Street           1706344
# 96858          No                 15  Shopping Centre           1657769
#
#           30 min population  20 min population  10 min population  Store age  \
# Store ID
# 99854               1307752            1159859            1020940          8
# 96858               1424404            1378708            1160929          5
#
#           Clearance space  Competition number  Competition score   Profit  \
# Store ID
# 99854                 276                  18                 13  3485295
# 96858                 203                  13                 18  2589339
#
#          Performance
# ...

# %%
#print de plaats (town) en het aantal medewerkers (Staff) van de winkels 81258 en 82709. Pas hierbij de loc method toe.
print(storedata.loc[[81258, 82709],["Town", "Staff"]])
print(type(storedata.loc[[81258, 82709],["Town", "Staff"]]))
# Out:
#                       Town  Staff
# Store ID
# 81258           Shrewsbury      7
# 82709      South Petherton      6
# <class 'pandas.core.frame.DataFrame'>

# %%
#Print de Town, Manager en Staff kolommen waarbij je gebruik maakt van de iloc methode.
print(storedata.iloc[:, [0,2,3]])
print(type(storedata.iloc[:, [0,2,3]]))
# Out:
#                                    Town Manager name  Staff
# Store ID
# 1437       Swinton (Greater Manchester)        Roger      9
# 1544                           Stamford         Ella      8
# 2039                            Skipton    Valentina      2
# 2055                           Stratton      Antonia      7
# 2141                         Shepperton      Gabriel      7
# ...                                 ...          ...    ...
# 96853                    South Benfleet      Vitória      7
# 96858                             Sandy       Matías      6
# 98062                         Sheerness      Gustavo      7
# 98923                           Salford       Rafael      6
# 99854                        Stapleford          Lea      9
#
# [136 rows x 3 columns]
# <class 'pandas.core.frame.DataFrame'>
